# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeshambav/DeepLearning_training/blob/main/Deeplearning_LSTM_Fake_News_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d68e462-4a17-4eae-83d7-06c56e672181" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d68e462-4a17-4eae-83d7-06c56e672181">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
file_path_merged = 'Train.csv'
df=pd.read_csv(file_path_merged)

# %%
df.head()
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
df.shape
# Out:
# (40000, 2)

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
# Drop Nan value
df = df.dropna()

# %%
df.shape
# Out:
# (40000, 2)

# %%
df.head()
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
df['text']
# Out:
# 0        I grew up (b. 1965) watching and loving the Th...
# 1        When I put this movie in my DVD player, and sa...
# 2        Why do people who do not know what a particula...
# 3        Even though I have great interest in Biblical ...
# 4        Im a die hard Dads Army fan and nothing will e...
#                                ...
# 39995    "Western Union" is something of a forgotten cl...
# 39996    This movie is an incredible piece of work. It ...
# 39997    My wife and I watched this movie because we pl...
# 39998    When I first watched Flatliners, I was amazed....
# 39999    Why would this film be so good, but only gross...
# Name: text, Length: 40000, dtype: object

# %%
## Get the Independent Features

X=df['text']

# %%
X.head()
# Out:
# 0    I grew up (b. 1965) watching and loving the Th...
# 1    When I put this movie in my DVD player, and sa...
# 2    Why do people who do not know what a particula...
# 3    Even though I have great interest in Biblical ...
# 4    Im a die hard Dads Army fan and nothing will e...
# Name: text, dtype: object

# %%
## Get the Dependent features
y=df['label']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: label, dtype: int64

# %%
X.shape
# Out:
# (40000,)

# %%
y.shape
# Out:
# (40000,)

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
### Set Vocabulary size a dictinary of words
voc_size=5000

# %%
### One Hot represenation
messages=X.copy()

# %%
df['text'][1]
# Out:
# "When I put this movie in my DVD player, and sat down with a coke and some chips, I had some expectations. I was hoping that this movie would contain some of the strong-points of the first movie: Awsome animation, good flowing story, excellent voice cast, funny comedy and a kick-ass soundtrack. But, to my disappointment, not any of this is to be found in Atlantis: Milo's Return. Had I read some reviews first, I might not have been so let down. The following paragraph will be directed to those who have seen the first movie, and who enjoyed it primarily for the points mentioned.<br /><br />When the first scene appears, your in for a shock if you just picked Atlantis: Milo's Return from the display-case at your local videoshop (or whatever), and had the expectations I had. The music feels as a bad imitation of the first movie, and the voice cast has been replaced by a not so fitting one. (With the exception of a few characters, like the voice of Sweet). The actual drawings isnt that bad
# ...

# %%
# Assuming messages is a DataFrame or a dictionary
df.text
# Out:
# 0        I grew up (b. 1965) watching and loving the Th...
# 1        When I put this movie in my DVD player, and sa...
# 2        Why do people who do not know what a particula...
# 3        Even though I have great interest in Biblical ...
# 4        Im a die hard Dads Army fan and nothing will e...
#                                ...
# 39995    "Western Union" is something of a forgotten cl...
# 39996    This movie is an incredible piece of work. It ...
# 39997    My wife and I watched this movie because we pl...
# 39998    When I first watched Flatliners, I was amazed....
# 39999    Why would this film be so good, but only gross...
# Name: text, Length: 40000, dtype: object

# %%
messages
# Out:
# 0        I grew up (b. 1965) watching and loving the Th...
# 1        When I put this movie in my DVD player, and sa...
# 2        Why do people who do not know what a particula...
# 3        Even though I have great interest in Biblical ...
# 4        Im a die hard Dads Army fan and nothing will e...
#                                ...
# 39995    "Western Union" is something of a forgotten cl...
# 39996    This movie is an incredible piece of work. It ...
# 39997    My wife and I watched this movie because we pl...
# 39998    When I first watched Flatliners, I was amazed....
# 39999    Why would this film be so good, but only gross...
# Name: text, Length: 40000, dtype: object

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
### Dataset Preprocessing
from nltk.stem.porter import PorterStemmer ##stemming purpose
ps = PorterStemmer()
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    review = review.lower()
    review = review.split()

    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
# from nltk.stem.porter import PorterStemmer
# ps = PorterStemmer()
# corpus = []

# # Assuming 'text' is the correct column name for text data
# for i in range(0, len(df)):
#     review = re.sub('[^a-zA-Z]', ' ', df['text'][i])  # Use the correct column name
#     review = review.lower()
#     review = review.split()

#     review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#     review = ' '.join(review)
#     corpus.append(review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2453288818bb> in <cell line: 6>()
#       4
#       5 # Assuming 'text' is the correct column name for text data
# ----> 6 for i in range(0, len(df)):
#       7     review = re.sub('[^a-zA-Z]', ' ', df['text'][i])  # Use the correct column name
#       8     review = review.lower()
#
# NameError: name 'df' is not defined

# %%
corpus[1]
# Out:
# 'put movi dvd player sat coke chip expect hope movi would contain strong point first movi awsom anim good flow stori excel voic cast funni comedi kick ass soundtrack disappoint found atlanti milo return read review first might let follow paragraph direct seen first movi enjoy primarili point mention br br first scene appear shock pick atlanti milo return display case local videoshop whatev expect music feel bad imit first movi voic cast replac fit one except charact like voic sweet actual draw isnt bad anim particular sad sight storylin also pretti weak like three episod schoobi doo singl adventur stori got last time dont misunderstand good schoobi doo episod didnt laugh singl time although might snigger twice br br audienc seen first movi especi care similar sequel fast review movi stand alon product like schoobi doo might like movi could still enjoy movi noth els suspect might good kid movi know might better milo return three episod seri cartoon channel breakfast tv'

# %%
onehot_repr=[one_hot(words,voc_size)for words in corpus]
onehot_repr
# Out:
# [[1128,
#   4977,
#   1938,
#   4191,
#   3492,
#   4935,
#   4331,
#   1938,
#   1870,
#   3492,
#   4331,
#   924,
#   4331,
#   1770,
#   2317,
#   576,
#   1235,
#   1770,
#   673,
#   3102,
#   1323,
#   2143,
#   3069,
#   2759,
#   1337,
#   753,
#   4947,
#   1861,
#   4955,
#   2669,
#   333,
#   4191,
#   3059,
#   2276,
#   3828,
#   4986,
#   2006,
#   465,
#   4460,
#   3481,
#   3146,
#   2184,
#   3222,
#   3446,
#   3492,
#   2751,
#   1099,
#   2536,
#   4955,
#   1235,
#   317,
#   3869,
#   1056,
#   1870,
#   2851,
#   3563,
#   4092,
#   4172,
#   3752,
#   1443,
#   1301,
#   2877,
#   3717,
#   3791,
#   533,
#   1960,
#   2972,
#   4259,
#   758,
#   3727,
#   4928,
#   794,
#   1363,
#   3233,
#   223,
#   3109,
#   2952,
#   4599,
#   4231,
#   4038,
#   504,
#   4038,
#   4837,
#   1737,
#   2329],
#  [4881,
#   4947,
#   2312,
#   2742,
#   3645,
#   692,
#   922,
#   500,
#   1861,
#   4947,
#   4955,
#   712,
#   2558,
#   2006,
#   1112,
#   4947,
# ...

# %%
corpus[1]
# Out:
# 'put movi dvd player sat coke chip expect hope movi would contain strong point first movi awsom anim good flow stori excel voic cast funni comedi kick ass soundtrack disappoint found atlanti milo return read review first might let follow paragraph direct seen first movi enjoy primarili point mention br br first scene appear shock pick atlanti milo return display case local videoshop whatev expect music feel bad imit first movi voic cast replac fit one except charact like voic sweet actual draw isnt bad anim particular sad sight storylin also pretti weak like three episod schoobi doo singl adventur stori got last time dont misunderstand good schoobi doo episod didnt laugh singl time although might snigger twice br br audienc seen first movi especi care similar sequel fast review movi stand alon product like schoobi doo might like movi could still enjoy movi noth els suspect might good kid movi know might better milo return three episod seri cartoon channel breakfast tv'

# %%
onehot_repr[1]
# Out:
# [4881,
#  4947,
#  2312,
#  2742,
#  3645,
#  692,
#  922,
#  500,
#  1861,
#  4947,
#  4955,
#  712,
#  2558,
#  2006,
#  1112,
#  4947,
#  3497,
#  1988,
#  4875,
#  4468,
#  4740,
#  3417,
#  1792,
#  4359,
#  2224,
#  2688,
#  4650,
#  942,
#  2028,
#  3828,
#  3212,
#  1215,
#  186,
#  1640,
#  3940,
#  4357,
#  1112,
#  2326,
#  2158,
#  3077,
#  1581,
#  2609,
#  4112,
#  1112,
#  4947,
#  4530,
#  3235,
#  2006,
#  4265,
#  2905,
#  2905,
#  1112,
#  4103,
#  259,
#  2296,
#  3517,
#  1215,
#  186,
#  1640,
#  469,
#  1678,
#  3849,
#  2613,
#  3465,
#  500,
#  4973,
#  4919,
#  3009,
#  4927,
#  1112,
#  4947,
#  1792,
#  4359,
#  2952,
#  821,
#  1235,
#  3856,
#  743,
#  4422,
#  1792,
#  2138,
#  1054,
#  43,
#  2970,
#  3009,
#  1988,
#  809,
#  2627,
#  1707,
#  103,
#  4794,
#  423,
#  4726,
#  4422,
#  3215,
#  2211,
#  4573,
#  2139,
#  1100,
#  4776,
#  4740,
#  2117,
#  4689,
#  2172,
#  4018,
#  82,
#  4875,
#  4573,
#  2139,
#  2211,
#  3676,
#  3381,
#  1100,
# ...

# %%
# Embedding Representation
sent_length=20
embedded_docs=pad_sequences(onehot_repr,padding='post',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[1960 2972 4259 ... 4837 1737 2329]
#  [4947 2213 2639 ... 3869 1691  389]
#  [4152 3059 2823 ...  322 3727  952]
#  ...
#  [1552 4359   56 ...  290 4408 2109]
#  [2905 2905 4740 ... 4253 2905 2905]
#  [4103  288 2182 ... 3940 2838 3678]]

# %%
embedded_docs[1]
# Out:
# array([4947, 2213, 2639, 4818, 2326, 4875, 3336, 4947, 3776, 2326, 2006,
#         186, 1640, 3215, 2211, 3563, 1435, 3869, 1691,  389], dtype=int32)

# %%
embedded_docs[0]
# Out:
# array([1960, 2972, 4259,  758, 3727, 4928,  794, 1363, 3233,  223, 3109,
#        2952, 4599, 4231, 4038,  504, 4038, 4837, 1737, 2329], dtype=int32)

# %%
## Creating model
embedding_vector_features=40 ##features representation
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(LSTM(100))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 20, 40)            200000
#
#  lstm (LSTM)                 (None, 100)               56400
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 256,501
# Trainable params: 256,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
len(embedded_docs),y.shape
# Out:
# (40000, (40000,))

# %%
import numpy as np
X_final=np.array(embedded_docs)
y_final=np.array(y)

# %%
X_final.shape,y_final.shape
# Out:
# ((40000, 20), (40000,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)

# %%
### Finally Training
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 419/419 [==============================] - 23s 45ms/step - loss: 0.5309 - accuracy: 0.7230 - val_loss: 0.4853 - val_accuracy: 0.7654
# Epoch 2/10
# 419/419 [==============================] - 18s 42ms/step - loss: 0.4341 - accuracy: 0.7979 - val_loss: 0.4811 - val_accuracy: 0.7664
# Epoch 3/10
# 419/419 [==============================] - 20s 48ms/step - loss: 0.3994 - accuracy: 0.8209 - val_loss: 0.4923 - val_accuracy: 0.7589
# Epoch 4/10
# 419/419 [==============================] - 18s 42ms/step - loss: 0.3648 - accuracy: 0.8397 - val_loss: 0.5222 - val_accuracy: 0.7556
# Epoch 5/10
# 419/419 [==============================] - 20s 48ms/step - loss: 0.3290 - accuracy: 0.8572 - val_loss: 0.5643 - val_accuracy: 0.7475
# Epoch 6/10
# 419/419 [==============================] - 17s 41ms/step - loss: 0.2832 - accuracy: 0.8787 - val_loss: 0.6298 - val_accuracy: 0.7429
# Epoch 7/10
# ...

# %%
# Adding drop out if required
from tensorflow.keras.layers import Dropout
## Creating model
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# Performance Metrics And Accuracy
y_pred=model.predict(X_test)
# Out:
# 413/413 [==============================] - 4s 7ms/step

# %%
y_pred=np.where(y_pred > 0.6, 1,0) ##AUC ROC Curve

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[6545,    0],
#        [6655,    0]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.49583333333333335

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.66      6545
#            1       0.00      0.00      0.00      6655
#
#     accuracy                           0.50     13200
#    macro avg       0.25      0.50      0.33     13200
# weighted avg       0.25      0.50      0.33     13200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
