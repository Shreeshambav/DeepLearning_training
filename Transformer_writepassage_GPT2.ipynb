# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeshambav/DeepLearning_training/blob/main/Transformer_writepassage_GPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
model = GPT2LMHeadModel.from_pretrained('gpt2-large', pad_token_id = tokenizer.eos_token_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
tokenizer.eos_token_id
# Out:
# 50256

# %%
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
sentence = 'Who is Shree Shambav?'
numeric_ids = tokenizer.encode(sentence, return_tensors ='pt')

# %%
numeric_ids
# Out:
# tensor([[8241,  318,  911,  631,  911, 4131,  615,   30]])

# %%
tokenizer.decode(numeric_ids[0][1])
# Out:
# ' is'

# %%
result = model.generate(numeric_ids, max_length=100, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
result
# Out:
# tensor([[ 8241,   318,   911,   631,   911,  4131,   615,    30,   198,   198,
#           2484,   631,   318,   530,   286,   262,   749,  2968,  3891,   287,
#           3794,    13,   383,  1438,   318, 10944,   422,   262, 46178,  1573,
#            366,  1477,   631,     1,   543,  1724,   366, 22988,   913,     1,
#            393,   366,  9948,    76,  1911,   383,  1573,   318,   635,   973,
#            284,  6901,   257,  1048,   508,   318,  9480,    11, 12309,    11,
#            290,   857,   407,   905,  5895,   286,  8993,   393,  8993,    12,
#           5363,  4069,    13,   911,  6037,   389,  3177,   284,   307,   845,
#          12309,   290, 12309,    12, 33983,   661,    13,  1119,   389,   635,
#           1900,   329,   852,   845,  1611,   290,  2074,   378,   286,  1854]])

# %%
decoded_result = tokenizer.decode(result[0], skip_special_tokens=True)

# %%
decoded_result
# Out:
# 'Who is Shree Shambav?\n\nShree is one of the most popular names in India. The name is derived from the Sanskrit word "shree" which means "peaceful" or "calm". The word is also used to describe a person who is calm, peaceful, and does not show signs of anger or anger-related behavior. Shrees are considered to be very peaceful and peaceful-loving people. They are also known for being very kind and considerate of others'
